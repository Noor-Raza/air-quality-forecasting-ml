# %%
import boto3
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

### Access AWS

# AWS credentials and bucket details
aws_access_key = "your_access_key"
aws_secret_key = "your_secret_key"

# Initialize S3 client
s3 = boto3.client(
    's3',
    aws_access_key_id=aws_access_key,
    aws_secret_access_key=aws_secret_key
)

# %%
### Load Data

# File keys and download path
bucket_name = 'bcnairquality'
keys = ['202406_airquality_data.csv',
        '202407_airquality_data.csv',
        '202404_airquality_data.csv',
        '202403_airquality_data.csv',
        '202402_airquality_data.csv',
        '202401_airquality_data.csv',
        '202408_airquality_data.csv',
        '202411_airquality_data.csv',
        '202409_airquality_data.csv',
        '202410_airquality_data.csv',
        '202412_airquality_data.csv',
        '2023_weather_data.csv',
        '2024_weather_data.csv']
download_path = '/tmp/'

# Download files
for key in keys:
    try:
        s3.download_file(bucket_name, key, f"{download_path}{key}")
        print(f"Successfully downloaded {key}")
    except Exception as e:
        print(f"Error downloading {key}: {e}")

# Load files
raw_data = {}

try:
    for key in keys:
        raw_data[key] = pd.read_csv(f"{download_path}{key}")
    print(f"Successfully loaded datasets")
except Exception as e:
    print(f"Error processing {keys[0]}: {e}")
# Out:
# Successfully downloaded 202406_airquality_data.csv
# Successfully downloaded 202407_airquality_data.csv
# Successfully downloaded 202404_airquality_data.csv
# Successfully downloaded 202403_airquality_data.csv
# Successfully downloaded 202402_airquality_data.csv
# Successfully downloaded 202401_airquality_data.csv
# Successfully downloaded 202408_airquality_data.csv
# Successfully downloaded 202411_airquality_data.csv
# Successfully downloaded 202409_airquality_data.csv
# Successfully downloaded 202410_airquality_data.csv
# Successfully downloaded 202412_airquality_data.csv
# Successfully downloaded 2023_weather_data.csv
# Successfully downloaded 2024_weather_data.csv
# Successfully loaded datasets

# %%
### Combine airquality datasets

# Concatenate datasets
airquality_df = pd.concat([raw_data[key] for key in keys[:-2]])

# Create a 'date' column using the 'ANY', 'MES', and 'DIA' columns
airquality_df['DATE'] = pd.to_datetime(
    airquality_df[['ANY', 'MES', 'DIA']].astype(str).agg('-'.join, axis=1), errors='coerce'
)

## Print update
print("Successfully combined airquality data")
# Out:
# Successfully combined airquality data

# %%
### Combine weather datasets

# Strip quotes from column names
for key in keys[-2:]:
    raw_data[key].columns = raw_data[key].columns.str.strip('"')  # Remove quotes around column names

# Concatenate datasets
weather_df = pd.concat([raw_data[key] for key in keys[-2:]])

# Create a 'date' column
weather_df['DATE'] = pd.to_datetime(weather_df['DATA_LECTURA'], errors='coerce')

# Strip quotes from rows
weather_df = weather_df.map(lambda x: x.replace('"', '') if isinstance(x, str) else x)

## Print update
print("Successfully combined weather data")
# Out:
# Successfully combined weather data

# %%
### Merge datasets

# Aggregate weather data by day and acronym
weather_daily = weather_df.groupby(['DATE', 'ACRÒNIM']).agg({'VALOR': 'mean'}).reset_index()

# Pivot weather data to have one column per acronym
weather_daily_pivot = weather_daily.pivot(index='DATE', columns='ACRÒNIM', values='VALOR').reset_index()

# Reshape air quality data for hourly analysis
new_airquality_df = airquality_df.melt(
    id_vars=['DATE', 'ESTACIO', 'CODI_CONTAMINANT'],
    value_vars=[f'H{str(i).zfill(2)}' for i in range(1, 25)],
    var_name='HOUR',
    value_name='POLLUTION'
)

# Aggregate air quality data by day and pollutant type
airquality_no2 = new_airquality_df[new_airquality_df['CODI_CONTAMINANT'] == 8].groupby('DATE')['POLLUTION'].max().reset_index().rename(columns={'POLLUTION': 'MAX_NO2'})
airquality_pm10 = new_airquality_df[new_airquality_df['CODI_CONTAMINANT'] == 110].groupby('DATE')['POLLUTION'].mean().reset_index().rename(columns={'POLLUTION': 'AVG_PM10'})

# Combine datasets for both pollutants
airquality_daily_pivot = pd.merge(airquality_no2, airquality_pm10, on='DATE', how='outer')

# Merge airquality and weather datasets on date
daily_merged_df = pd.merge(weather_daily_pivot, airquality_daily_pivot, on='DATE', how='inner')

# Sort merged data by date column
data = daily_merged_df.sort_values(by='DATE')
data.reset_index(drop=True, inplace=True)

## Print update
print("Successfully merged datasets")
# Out:
# Successfully merged datasets

# %%
### Preprocess data

# Remove N/As
data = data.dropna()

# Derive temporal features
data['Day_of_Week'] = data['DATE'].dt.dayofweek  # Monday = 0, Sunday = 6
data['Is_Weekend'] = data['Day_of_Week'].apply(lambda x: 1 if x >= 5 else 0)  # Weekend = 1
data['Month'] = data['DATE'].dt.month  # Month as a number
data['Is_Spring'] = data['Month'].apply(lambda x: 1 if x in [3, 4, 5] else 0)  # Spring = 1
data['Is_Summer'] = data['Month'].apply(lambda x: 1 if x in [6, 7, 8] else 0)  # Summer = 1
data['Is_Autumn'] = data['Month'].apply(lambda x: 1 if x in [9, 10, 11] else 0)  # Autumn = 1
data['Is_Winter'] = data['Month'].apply(lambda x: 1 if x in [12, 1, 2] else 0)  # Winter = 1
data['Day_of_Year'] = data['DATE'].dt.dayofyear  # Day of the year (1-365)
data['Week_of_Year'] = data['DATE'].dt.isocalendar().week  # Week number of the year

# Define feature columns
weather_columns = weather_daily_pivot.columns.to_list()[1:]
temporal_columns = ['Day_of_Week', 'Is_Weekend', 'Month', 'Is_Spring', 'Is_Summer', 'Is_Autumn', 'Is_Winter', 'Day_of_Year', 'Week_of_Year']

## Print update
print("Successfully preprocessed data")
# Out:
# Successfully preprocessed data

# %%
### Define Model

# Define pipeline functions
scaler = StandardScaler()
model = RandomForestRegressor(random_state=42)

# Machine learning pipeline
pipe = Pipeline(steps=[
    ('scaler', scaler),
    ('regressor', model)
])

# Grid search parameters
param_grid = [
    {
        'regressor': [RandomForestRegressor(random_state=42)],
        'regressor__n_estimators': [50, 100, 200],
        'regressor__max_depth': [10, 20, None],
        'regressor__min_samples_split': [2, 5, 10]
    },
    {
        'regressor': [GradientBoostingRegressor(random_state=42)],
        'regressor__n_estimators': [50, 100, 200],
        'regressor__learning_rate': [0.01, 0.1, 0.2],
        'regressor__max_depth': [3, 5, 10]

    },
    {
        'regressor': [SVR()],
        'regressor__C': [0.1, 1, 10],
        'regressor__kernel': ['linear', 'rbf', 'poly'],
        'regressor__epsilon': [0.1, 0.2, 0.5]
    },
    {
        'regressor': [ElasticNet(random_state=42)],
        'regressor__alpha': [0.1, 1, 10],
        'regressor__l1_ratio': [0.1, 0.5, 0.9]
    }
]

# Grid search with cross-validation
grid = GridSearchCV(pipe, param_grid, cv=5, verbose=1, scoring='r2')

## Print update
print("Successfully trained model")
# Out:
# Successfully trained model

# %%
### Fit NO2 Model

# Features and target selection
X_NO2 = data[weather_columns + temporal_columns]
y_NO2 = data['MAX_NO2']

# Split data into training and test sets (80% training, 20% test)
X_train_NO2, X_test_NO2, y_train_NO2, y_test_NO2 = train_test_split(X_NO2, y_NO2, test_size=0.2, random_state=42)

# Fit the model
grid.fit(X_train_NO2, y_train_NO2)

# Select best model and generalization score
best_model_NO2 = grid.best_estimator_

# Predict y
y_pred_NO2 = best_model_NO2.predict(X_test_NO2)

# Evaluate model
r2_NO2 = r2_score(y_test_NO2, y_pred_NO2)
mae_NO2 = mean_absolute_error(y_test_NO2, y_pred_NO2)
mse_NO2 = mean_squared_error(y_test_NO2, y_pred_NO2)

## Print update
print(f"Successfully fitted NO2 (R2: {r2_NO2:.2f}; MAE: {mae_NO2:.2f}; MSE: {mse_NO2:.2f})")
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# Successfully fitted NO2 (R2: 0.57; MAE: 10.22; MSE: 161.80)

# %%
### Fit PM10 Model

# Features and target selection
X_PM10 = data[weather_columns + temporal_columns]
y_PM10 = data['AVG_PM10']

# Split data into training and test sets (80% training, 20% test)
X_train_PM10, X_test_PM10, y_train_PM10, y_test_PM10 = train_test_split(X_PM10, y_PM10, test_size=0.2, random_state=42)

# Fit the model
grid.fit(X_train_PM10, y_train_PM10)

# Select best model and generalization score
best_model_PM10 = grid.best_estimator_

# Predict y
y_pred_PM10 = best_model_PM10.predict(X_test_PM10)

# Evaluate model
r2_PM10 = r2_score(y_test_PM10, y_pred_PM10)
mae_PM10 = mean_absolute_error(y_test_PM10, y_pred_PM10)
mse_PM10 = mean_squared_error(y_test_PM10, y_pred_PM10)

## Print update
print(f"Successfully fitted PM10 (R2: {r2_PM10:.2f}; MAE: {mae_PM10:.2f}; MSE: {mse_PM10:.2f})")
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# Successfully fitted PM10 (R2: 0.30; MAE: 4.78; MSE: 35.12)

# %%
### Get predictions

# Function to classify the thresholds for NO2 and PM10 (Source: https://ajuntament.barcelona.cat/qualitataire/en/air-quality/how-we-are-fighting-against-pollution/atmospheric-pollution-monitoring-and-forecasting)
def classify_no2(no2):
    if no2 <= 40:
        return 0
    elif no2 <= 90:
        return 1
    elif no2 <= 120:
        return 2
    elif no2 <= 230:
        return 3
    elif no2 <= 340:
        return 4
    else:
        return 5

def classify_pm10(pm10):
    if pm10 <= 20:
        return 0
    elif pm10 <= 40:
        return 1
    elif pm10 <= 50:
        return 2
    elif pm10 <= 100:
        return 3
    elif pm10 <= 150:
        return 4
    else:
        return 5

# Function to calculate the average weather for a given future date
def get_average_weather_for_future_date(day, month, year):
    input_date = pd.Timestamp(year=int(year), month=int(month), day=int(day))
    target_date = pd.to_datetime(input_date)
    prev_year_date = target_date.replace(year=target_date.year - 1)
    date_range = pd.date_range(prev_year_date - pd.Timedelta(days=1),
                               prev_year_date + pd.Timedelta(days=1), freq='D')
    weather_data = weather_daily_pivot.loc[weather_daily_pivot['DATE'].dt.date.isin(date_range.date)]

    if len(weather_data) < len(date_range):
        return None

    avg_weather = weather_data.mean()
    return avg_weather

# Function to get the predicted air pollution for a specific date
def predict_air_quality(day, month, year):
    try:
        avg_weather = get_average_weather_for_future_date(day, month, year)
        input_date = pd.Timestamp(year=int(year), month=int(month), day=int(day))

        if avg_weather is None:
            return "Unable to calculate weather for the given future date."

        features = {}
        weather_features = avg_weather[weather_columns]
        temporal_features = {
            'Day_of_Week': input_date.dayofweek,
            'Is_Weekend': 1 if input_date.weekday() >= 5 else 0,
            'Month': input_date.month,
            'Is_Spring': 1 if input_date.month in [3, 4, 5] else 0,
            'Is_Summer': 1 if input_date.month in [6, 7, 8] else 0,
            'Is_Autumn': 1 if input_date.month in [9, 10, 11] else 0,
            'Is_Winter': 1 if input_date.month in [12, 1, 2] else 0,
            'Day_of_Year': input_date.dayofyear,
            'Week_of_Year': input_date.isocalendar()[1]
        }
        features = {**weather_features, **temporal_features}
        features_df = pd.DataFrame([features], columns=features.keys())

        NO2_pred = best_model_NO2.predict(features_df)
        PM10_pred = best_model_PM10.predict(features_df)

        NO2_class = classify_no2(NO2_pred[0])
        PM10_class = classify_pm10(PM10_pred[0])

        EQAB_rank = max(NO2_class, PM10_class)

        conditions = ["Good", "Fair", "Moderate", "Poor", "Very Poor", "Extremely Poor"]
        health_impacts = [
            "Air quality is satisfactory, and air pollution poses little or no risk.",
            "Air quality is acceptable; however, some pollutants may pose a moderate health concern for a very small number of individuals who are unusually sensitive to air pollution.",
            "Members of sensitive groups may experience health effects; the general public is less likely to be affected.",
            "Everyone may begin to experience health effects; members of sensitive groups may experience more serious health effects.",
            "Alert; The risk of health effects is increased for everyone.",
            "Health warnings of emergency conditions; the entire population is more likely to be affected."
        ]
        recommendations = [
            "No specific actions needed; normal outdoor activities can be enjoyed.",
            "Sensitive individuals should consider limiting prolonged outdoor exertion.",
            "Sensitive groups (e.g., children, elderly, individuals with respiratory or heart conditions) should reduce prolonged or heavy outdoor exertion.",
            "Sensitive groups should avoid prolonged or heavy outdoor exertion; the general public should reduce prolonged or heavy outdoor exertion.",
            "Sensitive groups should avoid all outdoor exertion; the general public should avoid prolonged or heavy outdoor exertion.",
            "Everyone should avoid all outdoor exertion; follow any additional advice from health authorities."
        ]
        
        return_date = input_date.strftime('%d. %B %Y')
        return_condition = conditions[EQAB_rank]
        return_health_impact = health_impacts[EQAB_rank]
        return_recommendation = recommendations[EQAB_rank]
        return_max_NO2 = round(float(NO2_pred[0]), ndigits=2)
        return_avg_PM10 = round(float(PM10_pred[0]), ndigits=2)
        return_avg_temperature = avg_weather['TM']
        return_max_temperature = avg_weather['TX']
        return_min_temperature = avg_weather['TN']
        return_avg_humidity = avg_weather['HRM']
        return_max_humidity = avg_weather['HRX']
        return_min_humidity = avg_weather['HRN']
        return_avg_atmosphere = avg_weather['PM']
        return_max_atmosphere = avg_weather['PX']
        return_min_atmosphere = avg_weather['PN']
        return_percipitation = avg_weather['PPT']
        return_avg_wind = avg_weather['VVM10']
        return_max_wind = avg_weather['VVX10']

        return f"""
        On {return_date} the air quality will be {return_condition}.

        Health impact: {return_health_impact}
        Recommendation: {return_recommendation}
        
        Predicted pollutants:
         - Max. NO2: {return_max_NO2}
         - Avg. PM10: {return_avg_PM10}
        
        Weather forecast:
         - Temperature: Avg. {return_avg_temperature:.2f}°C; Max. {return_max_temperature:.2f}°C; Min. {return_min_temperature:.2f}°C
         - Humidity: Avg. {return_avg_humidity:.2f}%; Max. {return_max_humidity:.2f}%; Min. {return_min_humidity:.2f}%
         - Atmospheric pressure: Avg. {return_avg_atmosphere:.2f}hPa; Max. {return_max_atmosphere:.2f}hPa; Min. {return_min_atmosphere:.2f}hPa
         - Percipitation: Cum. {return_percipitation:.2f}mm
         - Wind: Avg. {return_avg_wind:.2f}m/s; Max. {return_max_wind:.2f}m/s
        """

    except Exception as e:
        return f"Error in prediction: {str(e)}"

# %%
get_average_weather_for_future_date(8, 6, 2025)['TX']
# Out:
# 26.625

# %%
X = predict_air_quality(8, 6, 2025)
print(X)
# Out:
#         On 08. June 2025 the air quality will be Good.
#
#         Health impact: Air quality is satisfactory, and air pollution poses little or no risk.
#         Recommendation: No specific actions needed; normal outdoor activities can be enjoyed.
#
#         Predicted pollutants:
#          - Max. NO2: 34.28
#          - Avg. PM10: 13.44
#
#         Weather forecast:
#          - Temperature: Avg. 22.90°C; Max. 26.62°C; Min. 20.15°C
#          - Humidity: Avg. 61.83%; Max. 82.92%; Min. 42.33%
#          - Atmospheric pressure: Avg. 990.90hPa; Max. 994.54hPa; Min. 988.04hPa
#          - Percipitation: Cum. 1.29mm
#          - Wind: Avg. 3.38m/s; Max. 10.47m/s

# %%
# Generate a list of all days in 2024
days_2024 = pd.date_range(start="2024-12-13", end="2025-12-12", freq='D')

# Convert to a list
days_list = days_2024.tolist()

for date in days_list:
    day = date.day
    month = date.month
    year = date.year
    result = predict_air_quality(day, month, year)
    print(result)
# Out:
#         On 13. December 2024 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 78.79
#          - Avg. PM10: 15.24)
#
#         The weather will
#
#
#         On 14. December 2024 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 68.3
#          - Avg. PM10: 13.15)
#
#         The weather will
#
#
#         On 15. December 2024 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 75.8
#          - Avg. PM10: 15.01)
#
#         The weather will
#
#
#         On 16. December 2024 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 95.47
#          - Avg. PM10: 21.1)
#
#         The weather will
#
#
#         On 17. December 2024 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 96.12
#          - Avg. PM10: 21.37)
#
#         The weather will
#
#
#         On 18. December 2024 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 97.77
#          - Avg. PM10: 20.11)
#
#         The weather will
#
#
#         On 19. December 2024 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 92.84
#          - Avg. PM10: 17.34)
#
#         The weather will
#
#
#         On 20. December 2024 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 81.02
#          - Avg. PM10: 14.41)
#
#         The weather will
#
#
#         On 21. December 2024 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 61.62
#          - Avg. PM10: 11.94)
#
#         The weather will
#
#
#         On 22. December 2024 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 60.07
#          - Avg. PM10: 11.67)
#
#         The weather will
#
#
#         On 23. December 2024 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 77.16
#          - Avg. PM10: 17.05)
#
#         The weather will
#
#
#         On 24. December 2024 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 80.66
#          - Avg. PM10: 17.14)
#
#         The weather will
#
#
#         On 25. December 2024 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 87.93
#          - Avg. PM10: 17.52)
#
#         The weather will
#
#
#         On 26. December 2024 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 94.61
#          - Avg. PM10: 17.07)
#
#         The weather will
#
#
#         On 27. December 2024 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 89.83
#          - Avg. PM10: 16.73)
#
#         The weather will
#
#
#         On 28. December 2024 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 72.01
#          - Avg. PM10: 14.29)
#
#         The weather will
#
#
#         On 29. December 2024 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 66.55
#          - Avg. PM10: 14.6)
#
#         The weather will
#
#
#         On 30. December 2024 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 65.5
#          - Avg. PM10: 18.19)
#
#         The weather will
#
#
#         On 31. December 2024 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 63.0
#          - Avg. PM10: 17.77)
#
#         The weather will
#
#
#         On 01. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 78.97
#          - Avg. PM10: 14.31)
#
#         The weather will
#
#
#         On 02. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 80.59
#          - Avg. PM10: 14.54)
#
#         The weather will
#
#
#         On 03. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 81.43
#          - Avg. PM10: 14.64)
#
#         The weather will
#
#
#         On 04. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 58.91
#          - Avg. PM10: 11.97)
#
#         The weather will
#
#
#         On 05. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 46.77
#          - Avg. PM10: 7.72)
#
#         The weather will
#
#
#         On 06. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 54.22
#          - Avg. PM10: 8.02)
#
#         The weather will
#
#
#         On 07. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 56.84
#          - Avg. PM10: 5.71)
#
#         The weather will
#
#
#         On 08. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 61.83
#          - Avg. PM10: 7.05)
#
#         The weather will
#
#
#         On 09. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 64.94
#          - Avg. PM10: 9.78)
#
#         The weather will
#
#
#         On 10. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 62.93
#          - Avg. PM10: 11.19)
#
#         The weather will
#
#
#         On 11. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 44.53
#          - Avg. PM10: 8.3)
#
#         The weather will
#
#
#         On 12. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 46.46
#          - Avg. PM10: 7.42)
#
#         The weather will
#
#
#         On 13. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 68.46
#          - Avg. PM10: 12.27)
#
#         The weather will
#
#
#         On 14. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 74.31
#          - Avg. PM10: 13.14)
#
#         The weather will
#
#
#         On 15. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 74.94
#          - Avg. PM10: 13.69)
#
#         The weather will
#
#
#         On 16. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 71.02
#          - Avg. PM10: 13.04)
#
#         The weather will
#
#
#         On 17. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 71.88
#          - Avg. PM10: 11.79)
#
#         The weather will
#
#
#         On 18. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 55.46
#          - Avg. PM10: 9.55)
#
#         The weather will
#
#
#         On 19. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 56.69
#          - Avg. PM10: 9.58)
#
#         The weather will
#
#
#         On 20. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 75.42
#          - Avg. PM10: 16.28)
#
#         The weather will
#
#
#         On 21. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 78.82
#          - Avg. PM10: 15.6)
#
#         The weather will
#
#
#         On 22. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 85.0
#          - Avg. PM10: 17.22)
#
#         The weather will
#
#
#         On 23. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 89.56
#          - Avg. PM10: 18.42)
#
#         The weather will
#
#
#         On 24. January 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 97.39
#          - Avg. PM10: 20.14)
#
#         The weather will
#
#
#         On 25. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 88.65
#          - Avg. PM10: 18.44)
#
#         The weather will
#
#
#         On 26. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 87.31
#          - Avg. PM10: 16.95)
#
#         The weather will
#
#
#         On 27. January 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 95.92
#          - Avg. PM10: 20.57)
#
#         The weather will
#
#
#         On 28. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 88.78
#          - Avg. PM10: 19.75)
#
#         The weather will
#
#
#         On 29. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 87.98
#          - Avg. PM10: 19.88)
#
#         The weather will
#
#
#         On 30. January 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 89.29
#          - Avg. PM10: 19.3)
#
#         The weather will
#
#
#         On 31. January 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 91.42
#          - Avg. PM10: 18.28)
#
#         The weather will
#
#
#         On 01. February 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 75.6
#          - Avg. PM10: 15.89)
#
#         The weather will
#
#
#         On 02. February 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 78.07
#          - Avg. PM10: 15.39)
#
#         The weather will
#
#
#         On 03. February 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 98.34
#          - Avg. PM10: 20.36)
#
#         The weather will
#
#
#         On 04. February 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 99.86
#          - Avg. PM10: 19.63)
#
#         The weather will
#
#
#         On 05. February 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 94.99
#          - Avg. PM10: 18.36)
#
#         The weather will
#
#
#         On 06. February 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 86.75
#          - Avg. PM10: 16.05)
#
#         The weather will
#
#
#         On 07. February 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 79.63
#          - Avg. PM10: 13.84)
#
#         The weather will
#
#
#         On 08. February 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 57.76
#          - Avg. PM10: 10.4)
#
#         The weather will
#
#
#         On 09. February 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 47.06
#          - Avg. PM10: 8.39)
#
#         The weather will
#
#
#         On 10. February 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 51.78
#          - Avg. PM10: 9.54)
#
#         The weather will
#
#
#         On 11. February 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 60.16
#          - Avg. PM10: 8.93)
#
#         The weather will
#
#
#         On 12. February 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 69.9
#          - Avg. PM10: 10.09)
#
#         The weather will
#
#
#         On 13. February 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 85.83
#          - Avg. PM10: 14.88)
#
#         The weather will
#
#
#         On 14. February 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 88.55
#          - Avg. PM10: 17.25)
#
#         The weather will
#
#
#         On 15. February 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 72.05
#          - Avg. PM10: 16.24)
#
#         The weather will
#
#
#         On 16. February 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 70.33
#          - Avg. PM10: 15.62)
#
#         The weather will
#
#
#         On 17. February 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 87.23
#          - Avg. PM10: 19.19)
#
#         The weather will
#
#
#         On 18. February 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 96.11
#          - Avg. PM10: 18.8)
#
#         The weather will
#
#
#         On 19. February 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 94.74
#          - Avg. PM10: 17.33)
#
#         The weather will
#
#
#         On 20. February 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 87.12
#          - Avg. PM10: 16.55)
#
#         The weather will
#
#
#         On 21. February 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 79.93
#          - Avg. PM10: 15.31)
#
#         The weather will
#
#
#         On 22. February 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 55.88
#          - Avg. PM10: 9.51)
#
#         The weather will
#
#
#         On 23. February 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 54.06
#          - Avg. PM10: 6.91)
#
#         The weather will
#
#
#         On 24. February 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 64.22
#          - Avg. PM10: 9.37)
#
#         The weather will
#
#
#         On 25. February 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 67.7
#          - Avg. PM10: 10.27)
#
#         The weather will
#
#
#         On 26. February 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 68.12
#          - Avg. PM10: 10.26)
#
#         The weather will
#
#
#         On 27. February 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 74.51
#          - Avg. PM10: 9.75)
#
#         The weather will
#
#
#         On 28. February 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 77.59
#          - Avg. PM10: 8.98)
#
#         The weather will
#
#
#         On 01. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 62.24
#          - Avg. PM10: 1.89)
#
#         The weather will
#
#
#         On 02. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 53.04
#          - Avg. PM10: 0.38)
#
#         The weather will
#
#
#         On 03. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 70.31
#          - Avg. PM10: 5.01)
#
#         The weather will
#
#
#         On 04. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 77.79
#          - Avg. PM10: 6.6)
#
#         The weather will
#
#
#         On 05. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 84.72
#          - Avg. PM10: 8.69)
#
#         The weather will
#
#
#         On 06. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 84.51
#          - Avg. PM10: 10.18)
#
#         The weather will
#
#
#         On 07. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 74.42
#          - Avg. PM10: 7.49)
#
#         The weather will
#
#
#         On 08. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 50.27
#          - Avg. PM10: 2.86)
#
#         The weather will
#
#
#         On 09. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 45.03
#          - Avg. PM10: 0.21)
#
#         The weather will
#
#
#         On 10. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 64.86
#          - Avg. PM10: 5.47)
#
#         The weather will
#
#
#         On 11. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 74.43
#          - Avg. PM10: 6.72)
#
#         The weather will
#
#
#         On 12. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 80.83
#          - Avg. PM10: 7.68)
#
#         The weather will
#
#
#         On 13. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 80.76
#          - Avg. PM10: 7.47)
#
#         The weather will
#
#
#         On 14. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 81.63
#          - Avg. PM10: 7.82)
#
#         The weather will
#
#
#         On 15. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 70.05
#          - Avg. PM10: 6.85)
#
#         The weather will
#
#
#         On 16. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 74.11
#          - Avg. PM10: 7.7)
#
#         The weather will
#
#
#         On 17. March 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 91.87
#          - Avg. PM10: 12.45)
#
#         The weather will
#
#
#         On 18. March 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 92.54
#          - Avg. PM10: 11.35)
#
#         The weather will
#
#
#         On 19. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 89.8
#          - Avg. PM10: 10.41)
#
#         The weather will
#
#
#         On 20. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 87.68
#          - Avg. PM10: 10.14)
#
#         The weather will
#
#
#         On 21. March 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 92.38
#          - Avg. PM10: 10.67)
#
#         The weather will
#
#
#         On 22. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 81.41
#          - Avg. PM10: 8.83)
#
#         The weather will
#
#
#         On 23. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 79.7
#          - Avg. PM10: 8.42)
#
#         The weather will
#
#
#         On 24. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 83.16
#          - Avg. PM10: 11.79)
#
#         The weather will
#
#
#         On 25. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 73.04
#          - Avg. PM10: 8.5)
#
#         The weather will
#
#
#         On 26. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 63.34
#          - Avg. PM10: 3.95)
#
#         The weather will
#
#
#         On 27. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 60.93
#          - Avg. PM10: 1.52)
#
#         The weather will
#
#
#         On 28. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 62.11
#          - Avg. PM10: 2.8)
#
#         The weather will
#
#
#         On 29. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 47.8
#          - Avg. PM10: 1.16)
#
#         The weather will
#
#
#         On 30. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 44.81
#          - Avg. PM10: 1.4)
#
#         The weather will
#
#
#         On 31. March 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 65.43
#          - Avg. PM10: 5.32)
#
#         The weather will
#
#
#         On 01. April 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 73.02
#          - Avg. PM10: 6.45)
#
#         The weather will
#
#
#         On 02. April 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 85.87
#          - Avg. PM10: 6.77)
#
#         The weather will
#
#
#         On 03. April 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 88.01
#          - Avg. PM10: 7.5)
#
#         The weather will
#
#
#         On 04. April 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 93.24
#          - Avg. PM10: 9.08)
#
#         The weather will
#
#
#         On 05. April 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 71.3
#          - Avg. PM10: 7.25)
#
#         The weather will
#
#
#         On 06. April 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 67.34
#          - Avg. PM10: 6.87)
#
#         The weather will
#
#
#         On 07. April 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 77.9
#          - Avg. PM10: 12.54)
#
#         The weather will
#
#
#         On 08. April 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 82.45
#          - Avg. PM10: 12.39)
#
#         The weather will
#
#
#         On 09. April 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 87.44
#          - Avg. PM10: 11.25)
#
#         The weather will
#
#
#         On 10. April 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 93.11
#          - Avg. PM10: 9.1)
#
#         The weather will
#
#
#         On 11. April 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 101.96
#          - Avg. PM10: 9.36)
#
#         The weather will
#
#
#         On 12. April 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 96.16
#          - Avg. PM10: 7.92)
#
#         The weather will
#
#
#         On 13. April 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 102.62
#          - Avg. PM10: 8.0)
#
#         The weather will
#
#
#         On 14. April 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 115.55
#          - Avg. PM10: 12.24)
#
#         The weather will
#
#
#         On 15. April 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 103.15
#          - Avg. PM10: 10.11)
#
#         The weather will
#
#
#         On 16. April 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 87.09
#          - Avg. PM10: 7.54)
#
#         The weather will
#
#
#         On 17. April 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 79.42
#          - Avg. PM10: 6.49)
#
#         The weather will
#
#
#         On 18. April 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 77.31
#          - Avg. PM10: 6.17)
#
#         The weather will
#
#
#         On 19. April 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 64.32
#          - Avg. PM10: 4.26)
#
#         The weather will
#
#
#         On 20. April 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 63.65
#          - Avg. PM10: 3.14)
#
#         The weather will
#
#
#         On 21. April 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 78.37
#          - Avg. PM10: 7.72)
#
#         The weather will
#
#
#         On 22. April 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 76.88
#          - Avg. PM10: 6.97)
#
#         The weather will
#
#
#         On 23. April 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 71.65
#          - Avg. PM10: 4.37)
#
#         The weather will
#
#
#         On 24. April 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 69.4
#          - Avg. PM10: 3.42)
#
#         The weather will
#
#
#         On 25. April 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 67.39
#          - Avg. PM10: 3.05)
#
#         The weather will
#
#
#         On 26. April 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 53.59
#          - Avg. PM10: 3.91)
#
#         The weather will
#
#
#         On 27. April 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 58.13
#          - Avg. PM10: 6.25)
#
#         The weather will
#
#
#         On 28. April 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 74.93
#          - Avg. PM10: 8.11)
#
#         The weather will
#
#
#         On 29. April 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 74.95
#          - Avg. PM10: 7.36)
#
#         The weather will
#
#
#         On 30. April 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 76.79
#          - Avg. PM10: 5.17)
#
#         The weather will
#
#
#         On 01. May 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 76.29
#          - Avg. PM10: 7.66)
#
#         The weather will
#
#
#         On 02. May 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 81.57
#          - Avg. PM10: 5.67)
#
#         The weather will
#
#
#         On 03. May 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 69.08
#          - Avg. PM10: 2.86)
#
#         The weather will
#
#
#         On 04. May 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 70.44
#          - Avg. PM10: 3.54)
#
#         The weather will
#
#
#         On 05. May 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 85.86
#          - Avg. PM10: 10.0)
#
#         The weather will
#
#
#         On 06. May 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 82.44
#          - Avg. PM10: 9.9)
#
#         The weather will
#
#
#         On 07. May 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 85.69
#          - Avg. PM10: 8.03)
#
#         The weather will
#
#
#         On 08. May 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 88.47
#          - Avg. PM10: 5.43)
#
#         The weather will
#
#
#         On 09. May 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 95.11
#          - Avg. PM10: 5.01)
#
#         The weather will
#
#
#         On 10. May 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 82.46
#          - Avg. PM10: 3.01)
#
#         The weather will
#
#
#         On 11. May 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 85.73
#          - Avg. PM10: 5.1)
#
#         The weather will
#
#
#         On 12. May 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 98.87
#          - Avg. PM10: 10.51)
#
#         The weather will
#
#
#         On 13. May 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 91.9
#          - Avg. PM10: 11.22)
#
#         The weather will
#
#
#         On 14. May 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 84.37
#          - Avg. PM10: 10.43)
#
#         The weather will
#
#
#         On 15. May 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 80.39
#          - Avg. PM10: 10.47)
#
#         The weather will
#
#
#         On 16. May 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 80.45
#          - Avg. PM10: 9.59)
#
#         The weather will
#
#
#         On 17. May 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 62.45
#          - Avg. PM10: 6.2)
#
#         The weather will
#
#
#         On 18. May 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 60.0
#          - Avg. PM10: 4.47)
#
#         The weather will
#
#
#         On 19. May 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 78.29
#          - Avg. PM10: 9.58)
#
#         The weather will
#
#
#         On 20. May 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 83.76
#          - Avg. PM10: 9.12)
#
#         The weather will
#
#
#         On 21. May 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 88.73
#          - Avg. PM10: 10.01)
#
#         The weather will
#
#
#         On 22. May 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 86.95
#          - Avg. PM10: 8.29)
#
#         The weather will
#
#
#         On 23. May 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 86.13
#          - Avg. PM10: 7.47)
#
#         The weather will
#
#
#         On 24. May 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 73.21
#          - Avg. PM10: 5.09)
#
#         The weather will
#
#
#         On 25. May 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 77.5
#          - Avg. PM10: 6.15)
#
#         The weather will
#
#
#         On 26. May 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 92.79
#          - Avg. PM10: 11.56)
#
#         The weather will
#
#
#         On 27. May 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 90.69
#          - Avg. PM10: 10.66)
#
#         The weather will
#
#
#         On 28. May 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 91.69
#          - Avg. PM10: 10.38)
#
#         The weather will
#
#
#         On 29. May 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 93.34
#          - Avg. PM10: 10.44)
#
#         The weather will
#
#
#         On 30. May 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 91.92
#          - Avg. PM10: 9.17)
#
#         The weather will
#
#
#         On 31. May 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 76.67
#          - Avg. PM10: 6.82)
#
#         The weather will
#
#
#         On 01. June 2025 the air quality will be Good.
#
#         Predicted pollutants:
#          - Max. NO2: 26.66
#          - Avg. PM10: 12.67)
#
#         The weather will
#
#
#         On 02. June 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 45.54
#          - Avg. PM10: 17.59)
#
#         The weather will
#
#
#         On 03. June 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 42.86
#          - Avg. PM10: 16.33)
#
#         The weather will
#
#
#         On 04. June 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 42.29
#          - Avg. PM10: 15.86)
#
#         The weather will
#
#
#         On 05. June 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 47.89
#          - Avg. PM10: 16.09)
#
#         The weather will
#
#
#         On 06. June 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 54.03
#          - Avg. PM10: 16.15)
#
#         The weather will
#
#
#         On 07. June 2025 the air quality will be Good.
#
#         Predicted pollutants:
#          - Max. NO2: 38.79
#          - Avg. PM10: 13.82)
#
#         The weather will
#
#
#         On 08. June 2025 the air quality will be Good.
#
#         Predicted pollutants:
#          - Max. NO2: 34.28
#          - Avg. PM10: 13.44)
#
#         The weather will
#
#
#         On 09. June 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 48.45
#          - Avg. PM10: 19.05)
#
#         The weather will
#
#
#         On 10. June 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 56.25
#          - Avg. PM10: 19.1)
#
#         The weather will
#
#
#         On 11. June 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 54.18
#          - Avg. PM10: 19.21)
#
#         The weather will
#
#
#         On 12. June 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 46.72
#          - Avg. PM10: 16.88)
#
#         The weather will
#
#
#         On 13. June 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 41.06
#          - Avg. PM10: 17.45)
#
#         The weather will
#
#
#         On 14. June 2025 the air quality will be Good.
#
#         Predicted pollutants:
#          - Max. NO2: 23.98
#          - Avg. PM10: 13.24)
#
#         The weather will
#
#
#         On 15. June 2025 the air quality will be Good.
#
#         Predicted pollutants:
#          - Max. NO2: 27.87
#          - Avg. PM10: 12.95)
#
#         The weather will
#
#
#         On 16. June 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 42.61
#          - Avg. PM10: 16.45)
#
#         The weather will
#
#
#         On 17. June 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 42.92
#          - Avg. PM10: 16.72)
#
#         The weather will
#
#
#         On 18. June 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 44.31
#          - Avg. PM10: 18.38)
#
#         The weather will
#
#
#         On 19. June 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 44.81
#          - Avg. PM10: 18.95)
#
#         The weather will
#
#
#         On 20. June 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 48.99
#          - Avg. PM10: 19.22)
#
#         The weather will
#
#
#         On 21. June 2025 the air quality will be Good.
#
#         Predicted pollutants:
#          - Max. NO2: 35.82
#          - Avg. PM10: 17.02)
#
#         The weather will
#
#
#         On 22. June 2025 the air quality will be Good.
#
#         Predicted pollutants:
#          - Max. NO2: 37.15
#          - Avg. PM10: 16.81)
#
#         The weather will
#
#
#         On 23. June 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 53.44
#          - Avg. PM10: 22.16)
#
#         The weather will
#
#
#         On 24. June 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 48.44
#          - Avg. PM10: 19.3)
#
#         The weather will
#
#
#         On 25. June 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 49.19
#          - Avg. PM10: 18.08)
#
#         The weather will
#
#
#         On 26. June 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 51.93
#          - Avg. PM10: 16.63)
#
#         The weather will
#
#
#         On 27. June 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 56.64
#          - Avg. PM10: 16.58)
#
#         The weather will
#
#
#         On 28. June 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 43.58
#          - Avg. PM10: 15.09)
#
#         The weather will
#
#
#         On 29. June 2025 the air quality will be Good.
#
#         Predicted pollutants:
#          - Max. NO2: 39.02
#          - Avg. PM10: 15.55)
#
#         The weather will
#
#
#         On 30. June 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 58.51
#          - Avg. PM10: 22.6)
#
#         The weather will
#
#
#         On 01. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 52.3
#          - Avg. PM10: 21.49)
#
#         The weather will
#
#
#         On 02. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 52.07
#          - Avg. PM10: 20.83)
#
#         The weather will
#
#
#         On 03. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 47.41
#          - Avg. PM10: 19.17)
#
#         The weather will
#
#
#         On 04. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 50.6
#          - Avg. PM10: 18.84)
#
#         The weather will
#
#
#         On 05. July 2025 the air quality will be Good.
#
#         Predicted pollutants:
#          - Max. NO2: 36.61
#          - Avg. PM10: 16.61)
#
#         The weather will
#
#
#         On 06. July 2025 the air quality will be Good.
#
#         Predicted pollutants:
#          - Max. NO2: 37.49
#          - Avg. PM10: 16.47)
#
#         The weather will
#
#
#         On 07. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 51.16
#          - Avg. PM10: 20.73)
#
#         The weather will
#
#
#         On 08. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 55.22
#          - Avg. PM10: 20.27)
#
#         The weather will
#
#
#         On 09. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 58.96
#          - Avg. PM10: 19.36)
#
#         The weather will
#
#
#         On 10. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 64.77
#          - Avg. PM10: 20.56)
#
#         The weather will
#
#
#         On 11. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 64.67
#          - Avg. PM10: 21.04)
#
#         The weather will
#
#
#         On 12. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 47.94
#          - Avg. PM10: 19.16)
#
#         The weather will
#
#
#         On 13. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 41.2
#          - Avg. PM10: 16.99)
#
#         The weather will
#
#
#         On 14. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 54.91
#          - Avg. PM10: 21.52)
#
#         The weather will
#
#
#         On 15. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 55.67
#          - Avg. PM10: 21.07)
#
#         The weather will
#
#
#         On 16. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 60.48
#          - Avg. PM10: 20.87)
#
#         The weather will
#
#
#         On 17. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 65.65
#          - Avg. PM10: 19.5)
#
#         The weather will
#
#
#         On 18. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 69.89
#          - Avg. PM10: 19.83)
#
#         The weather will
#
#
#         On 19. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 56.21
#          - Avg. PM10: 18.44)
#
#         The weather will
#
#
#         On 20. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 54.43
#          - Avg. PM10: 19.63)
#
#         The weather will
#
#
#         On 21. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 68.43
#          - Avg. PM10: 22.78)
#
#         The weather will
#
#
#         On 22. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 70.16
#          - Avg. PM10: 22.14)
#
#         The weather will
#
#
#         On 23. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 70.24
#          - Avg. PM10: 20.43)
#
#         The weather will
#
#
#         On 24. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 67.76
#          - Avg. PM10: 20.18)
#
#         The weather will
#
#
#         On 25. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 67.97
#          - Avg. PM10: 19.28)
#
#         The weather will
#
#
#         On 26. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 56.94
#          - Avg. PM10: 17.34)
#
#         The weather will
#
#
#         On 27. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 57.88
#          - Avg. PM10: 17.06)
#
#         The weather will
#
#
#         On 28. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 77.78
#          - Avg. PM10: 22.54)
#
#         The weather will
#
#
#         On 29. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 84.14
#          - Avg. PM10: 22.87)
#
#         The weather will
#
#
#         On 30. July 2025 the air quality will be Moderate.
#
#         Predicted pollutants:
#          - Max. NO2: 93.74
#          - Avg. PM10: 22.8)
#
#         The weather will
#
#
#         On 31. July 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 88.4
#          - Avg. PM10: 21.64)
#
#         The weather will
#
#
#         On 01. August 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 77.14
#          - Avg. PM10: 20.21)
#
#         The weather will
#
#
#         On 02. August 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 53.41
#          - Avg. PM10: 17.65)
#
#         The weather will
#
#
#         On 03. August 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 53.14
#          - Avg. PM10: 18.81)
#
#         The weather will
#
#
#         On 04. August 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 66.04
#          - Avg. PM10: 23.7)
#
#         The weather will
#
#
#         On 05. August 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 65.99
#          - Avg. PM10: 23.61)
#
#         The weather will
#
#
#         On 06. August 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 66.96
#          - Avg. PM10: 21.68)
#
#         The weather will
#
#
#         On 07. August 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 70.46
#          - Avg. PM10: 21.47)
#
#         The weather will
#
#
#         On 08. August 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 75.58
#          - Avg. PM10: 21.36)
#
#         The weather will
#
#
#         On 09. August 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 64.8
#          - Avg. PM10: 19.28)
#
#         The weather will
#
#
#         On 10. August 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 59.97
#          - Avg. PM10: 18.72)
#
#         The weather will
#
#
#         On 11. August 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 69.14
#          - Avg. PM10: 23.25)
#
#         The weather will
#
#
#         On 12. August 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 65.6
#          - Avg. PM10: 24.66)
#
#         The weather will
#
#
#         On 13. August 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 68.17
#          - Avg. PM10: 24.83)
#
#         The weather will
#
#
#         On 14. August 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 73.21
#          - Avg. PM10: 25.3)
#
#         The weather will
#
#
#         On 15. August 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 74.6
# ...
#
#
#         On 21. September 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 57.49
#          - Avg. PM10: 15.34)
#
#         The weather will
#
#
#         On 22. September 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 69.31
#          - Avg. PM10: 21.07)
#
#         The weather will
#
#
#         On 23. September 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 73.75
#          - Avg. PM10: 20.9)
#
#         The weather will
#
#
#         On 24. September 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 72.36
#          - Avg. PM10: 18.46)
#
#         The weather will
#
#
#         On 25. September 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 76.41
#          - Avg. PM10: 17.55)
#
#         The weather will
#
#
#         On 26. September 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 77.57
#          - Avg. PM10: 16.38)
#
#         The weather will
#
#
#         On 27. September 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 64.28
#          - Avg. PM10: 13.48)
#
#         The weather will
#
#
#         On 28. September 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 62.62
#          - Avg. PM10: 12.95)
#
#         The weather will
#
#
#         On 29. September 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 74.8
#          - Avg. PM10: 18.12)
#
#         The weather will
#
#
#         On 30. September 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 72.2
#          - Avg. PM10: 19.38)
#
#         The weather will
#
#
#         On 01. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 67.68
#          - Avg. PM10: 17.93)
#
#         The weather will
#
#
#         On 02. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 65.32
#          - Avg. PM10: 15.42)
#
#         The weather will
#
#
#         On 03. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 64.03
#          - Avg. PM10: 12.88)
#
#         The weather will
#
#
#         On 04. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 50.43
#          - Avg. PM10: 11.7)
#
#         The weather will
#
#
#         On 05. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 53.98
#          - Avg. PM10: 12.88)
#
#         The weather will
#
#
#         On 06. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 69.16
#          - Avg. PM10: 20.55)
#
#         The weather will
#
#
#         On 07. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 67.44
#          - Avg. PM10: 19.02)
#
#         The weather will
#
#
#         On 08. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 60.31
#          - Avg. PM10: 16.72)
#
#         The weather will
#
#
#         On 09. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 60.17
#          - Avg. PM10: 13.16)
#
#         The weather will
#
#
#         On 10. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 60.8
#          - Avg. PM10: 14.26)
#
#         The weather will
#
#
#         On 11. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 51.57
#          - Avg. PM10: 14.66)
#
#         The weather will
#
#
#         On 12. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 52.06
#          - Avg. PM10: 16.29)
#
#         The weather will
#
#
#         On 13. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 65.55
#          - Avg. PM10: 21.89)
#
#         The weather will
#
#
#         On 14. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 62.01
#          - Avg. PM10: 21.37)
#
#         The weather will
#
#
#         On 15. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 63.74
#          - Avg. PM10: 21.99)
#
#         The weather will
#
#
#         On 16. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 66.58
#          - Avg. PM10: 21.5)
#
#         The weather will
#
#
#         On 17. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 65.14
#          - Avg. PM10: 19.25)
#
#         The weather will
#
#
#         On 18. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 51.97
#          - Avg. PM10: 14.6)
#
#         The weather will
#
#
#         On 19. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 58.51
#          - Avg. PM10: 13.71)
#
#         The weather will
#
#
#         On 20. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 79.56
#          - Avg. PM10: 19.19)
#
#         The weather will
#
#
#         On 21. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 78.78
#          - Avg. PM10: 20.63)
#
#         The weather will
#
#
#         On 22. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 75.99
#          - Avg. PM10: 20.87)
#
#         The weather will
#
#
#         On 23. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 77.01
#          - Avg. PM10: 21.65)
#
#         The weather will
#
#
#         On 24. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 76.44
#          - Avg. PM10: 20.89)
#
#         The weather will
#
#
#         On 25. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 54.95
#          - Avg. PM10: 15.81)
#
#         The weather will
#
#
#         On 26. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 46.78
#          - Avg. PM10: 13.29)
#
#         The weather will
#
#
#         On 27. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 58.47
#          - Avg. PM10: 16.71)
#
#         The weather will
#
#
#         On 28. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 55.18
#          - Avg. PM10: 17.36)
#
#         The weather will
#
#
#         On 29. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 55.42
#          - Avg. PM10: 16.38)
#
#         The weather will
#
#
#         On 30. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 55.44
#          - Avg. PM10: 16.91)
#
#         The weather will
#
#
#         On 31. October 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 59.32
#          - Avg. PM10: 17.63)
#
#         The weather will
#
#
#         On 01. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 43.32
#          - Avg. PM10: 16.93)
#
#         The weather will
#
#
#         On 02. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 42.75
#          - Avg. PM10: 16.63)
#
#         The weather will
#
#
#         On 03. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 58.06
#          - Avg. PM10: 19.47)
#
#         The weather will
#
#
#         On 04. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 63.61
#          - Avg. PM10: 21.0)
#
#         The weather will
#
#
#         On 05. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 66.89
#          - Avg. PM10: 20.5)
#
#         The weather will
#
#
#         On 06. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 66.31
#          - Avg. PM10: 21.03)
#
#         The weather will
#
#
#         On 07. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 64.81
#          - Avg. PM10: 18.73)
#
#         The weather will
#
#
#         On 08. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 51.07
#          - Avg. PM10: 15.77)
#
#         The weather will
#
#
#         On 09. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 54.01
#          - Avg. PM10: 15.17)
#
#         The weather will
#
#
#         On 10. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 71.85
#          - Avg. PM10: 20.09)
#
#         The weather will
#
#
#         On 11. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 67.67
#          - Avg. PM10: 17.67)
#
#         The weather will
#
#
#         On 12. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 57.07
#          - Avg. PM10: 15.78)
#
#         The weather will
#
#
#         On 13. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 51.77
#          - Avg. PM10: 14.12)
#
#         The weather will
#
#
#         On 14. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 54.16
#          - Avg. PM10: 15.06)
#
#         The weather will
#
#
#         On 15. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 49.98
#          - Avg. PM10: 14.61)
#
#         The weather will
#
#
#         On 16. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 49.7
#          - Avg. PM10: 14.49)
#
#         The weather will
#
#
#         On 17. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 63.13
#          - Avg. PM10: 19.37)
#
#         The weather will
#
#
#         On 18. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 61.77
#          - Avg. PM10: 18.39)
#
#         The weather will
#
#
#         On 19. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 59.0
#          - Avg. PM10: 17.1)
#
#         The weather will
#
#
#         On 20. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 57.69
#          - Avg. PM10: 15.24)
#
#         The weather will
#
#
#         On 21. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 57.56
#          - Avg. PM10: 13.64)
#
#         The weather will
#
#
#         On 22. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 47.11
#          - Avg. PM10: 12.55)
#
#         The weather will
#
#
#         On 23. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 51.89
#          - Avg. PM10: 15.36)
#
#         The weather will
#
#
#         On 24. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 67.02
#          - Avg. PM10: 23.46)
#
#         The weather will
#
#
#         On 25. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 69.63
#          - Avg. PM10: 23.03)
#
#         The weather will
#
#
#         On 26. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 69.75
#          - Avg. PM10: 20.45)
#
#         The weather will
#
#
#         On 27. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 72.31
#          - Avg. PM10: 17.76)
#
#         The weather will
#
#
#         On 28. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 71.18
#          - Avg. PM10: 17.31)
#
#         The weather will
#
#
#         On 29. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 57.56
#          - Avg. PM10: 16.59)
#
#         The weather will
#
#
#         On 30. November 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 56.53
#          - Avg. PM10: 17.39)
#
#         The weather will
#
#
#         On 01. December 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 89.32
#          - Avg. PM10: 22.71)
#
#         The weather will
#
#
#         On 02. December 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 84.7
#          - Avg. PM10: 20.18)
#
#         The weather will
#
#
#         On 03. December 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 81.18
#          - Avg. PM10: 18.13)
#
#         The weather will
#
#
#         On 04. December 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 77.07
#          - Avg. PM10: 16.31)
#
#         The weather will
#
#
#         On 05. December 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 77.77
#          - Avg. PM10: 16.72)
#
#         The weather will
#
#
#         On 06. December 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 64.2
#          - Avg. PM10: 15.14)
#
#         The weather will
#
#
#         On 07. December 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 53.9
#          - Avg. PM10: 12.47)
#
#         The weather will
#
#
#         On 08. December 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 57.95
#          - Avg. PM10: 13.29)
#
#         The weather will
#
#
#         On 09. December 2025 the air quality will be Fair.
#
#         Predicted pollutants:
#          - Max. NO2: 53.06
#          - Avg. PM10: 10.65)
#
#         The weather will
#
# Unable to calculate weather for the given future date.
# Unable to calculate weather for the given future date.
# Unable to calculate weather for the given future date.
